# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/AI/ML/MOVIES_RECOMMENNDATION_DATA/movies_recommendation_data.csv')

# %%
df
# Out:
#     Movie ID                        Movie Name  IMDB Rating  Biography  Drama  \
# 0         58                The Imitation Game          8.0          1      1
# 1          8                        Ex Machina          7.7          0      1
# 2         46                  A Beautiful Mind          8.2          1      1
# 3         62                 Good Will Hunting          8.3          0      1
# 4         97                      Forrest Gump          8.8          0      1
# 5         98                                21          6.8          0      1
# 6         31                            Gifted          7.6          0      1
# 7          3               Travelling Salesman          5.9          0      1
# 8         51                            Avatar          7.9          0      0
# 9         47                    The Karate Kid          7.2          0      1
# 10        50            A Brilliant Young Mind          7.2          0      1
# ...

# %%
X = df[['Biography','Drama','Thriller','Comedy','Crime','Mystery','History']]

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors()
model.fit(X.values)
# Out:
# NearestNeighbors()

# %%
Movie = [[0,1,1,0,1,0,0]]

# %%
neighbors = model.kneighbors(Movie, 5)
print(neighbors)
# Out:
# (array([[0.        , 1.41421356, 1.41421356, 1.41421356, 1.41421356]]), array([[11,  4,  3,  5,  0]]))

# %%
for index in neighbors[1]:
    print(df.iloc[index, 1])
# Out:
# 11        A Time To Kill
# 4           Forrest Gump
# 3      Good Will Hunting
# 5                     21
# 0     The Imitation Game
# Name: Movie Name, dtype: object
